# %% [markdown]
# ## Support Vector Machines Exercise
#
# This exercise will use a famous data set, the "Iris flower data set".
#
# The Iris flower data set or Fisher's Iris data set is a multivariate data set introduced by Sir Ronald Fisher in the 1936
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor), so 150 total samples. Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# A brief history of the data set as well as pictures of the Irises can be found here [Iris flower data set](http://en.wikipedia.org/wiki/Iris_flower_data_set).
#
# The iris dataset contains measurements for 150 iris flowers from three different species.
#
# The three classes in the Iris dataset:
#
#     Iris-setosa (n=50)
#     Iris-versicolor (n=50)
#     Iris-virginica (n=50)
#
# The four features of the Iris dataset:
#
#     sepal length in cm
#     sepal width in cm
#     petal length in cm
#     petal width in cm

# %% [markdown]
# ## Get the data
#
# **Use seaborn to get the iris data by using: iris = sns.load_dataset('iris')**

# %% [markdown]
# ## Exploratory Data Analysis
#
# **Import some libraries you think you'll need.**

# %% [markdown]
# **Create a pairplot of the data set.**

# %% [markdown]
# **Which flower species seems to be the most separable?**

# %% [markdown]
# **Create a kde plot of sepal_length versus sepal width for setosa species of flower.**

# %% [markdown]
# ## Train Test Split
#
# **Split your data into a training set and a testing set.**
# **Use test_size=0.30 and random_state=0  (so you get the same results shown)**

# %% [markdown]
# ## Train a Support Vector Machine Classifier Model
#
# **Use the SVC() model from sklearn and fit the model.**

# %%
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# ## Model Evaluation
#
# **Create a confusion matrix and a classification report.**

# %%
# Out:
# [[16  0  0]
#  [ 0 17  1]
#  [ 0  0 11]]

# %%
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        16
#   versicolor       1.00      0.94      0.97        18
#    virginica       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# **Wow!**
# You should have noticed that your model was pretty good!
# See if you can tune the parameters to try to do better (unlikely, and you probably would be satisfied with these results in real like because the data set is quite small, but I just want you to practice using GridSearch.

# %% [markdown]
# ## Gridsearch
#
# **Import GridsearchCV from SciKit Learn.**

# %% [markdown]
# **Create a dictionary called param_grid and fill out some parameters for C and gamma.**
# Your choice for the search grid. You do not have use the same region I did.

# %% [markdown]
# **Create a GridSearchCV object and fit it to the training data.**

# %%
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ...................... C=0.1, gamma=1, score=0.972, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ...................... C=0.1, gamma=1, score=0.829, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ...................... C=0.1, gamma=1, score=0.912, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] .................... C=0.1, gamma=0.1, score=0.861, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] .................... C=0.1, gamma=0.1, score=0.800, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] .................... C=0.1, gamma=0.1, score=0.853, total=   0.0s
# ...

# %% [markdown]
# **For your search values, what were the best parameters?**

# %%
# Out:
# {'C': 100, 'gamma': 0.1}

# %% [markdown]
# **Now take that grid model and create some predictions using the test set and create classification reports and confusion matrices for them.**

# %%
# Out:
# [[16  0  0]
#  [ 0 16  2]
#  [ 0  0 11]]

# %%
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        16
#   versicolor       1.00      0.89      0.94        18
#    virginica       0.85      1.00      0.92        11
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.96      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %% [markdown]
# ### How did you do
# **Were you able to improve?**
# You should have done about the same or exactly the same.
#
# If you did worse, It is because the parameters you searched over were not as good as the defaults use by SVC.
# From the slearn documention, the default parameters for C and gamma used by SVC are:
#  - C: float, default=1.0
#  - gamma{‘scale’, ‘auto’} or float, default=’scale’
#     - if gamma='scale' (default) is passed then it uses 1 / (n_features * X.var()) as value of gamma,
#     - if ‘auto’, uses 1 / n_features.
#
# **Experiment with the grid for the parameters. You might want to try searching "around" the defaults.**
